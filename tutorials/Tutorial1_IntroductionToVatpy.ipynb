# %% [markdown]
# # Vatpy Tutorial 1 - How to use TerminalPlot in Jupyter Notebooks

# %%
import numpy as np
import matplotlib.pyplot as plt

# for interactive plots, use widget instead of inline
# %matplotlib inline

# import vatpy
import vatpy as vp

# %% [markdown]
# ***

# %% [markdown]
# ## Step 1 - How to Make Plots of the Gas Density

# %% [markdown]
# Here we specify the file we want to explore, using the TerminalPlot class

# %%
file = '/srv/astro/projects/zoom/jpeterss/accretion/dwarf/highres/h1b4_SNRT/OUTPUT/snap_400.hdf5'
tp = vp.TerminalPlot(file=file, savepath='plots/', saveformat='png', unitlength='kpc')

# %%
tp.density()
# Out:
#   * Figure generated and saved
#   * Interactive display of the figure is now running
